# %% [markdown]
# ### install panda dan numpy jika belum tersedia

# %%
#!pip install pandas
#!pip install numpy

# %% [markdown]
# ### import numpy dan panda dan dibuatkan alias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### merubah separator antar data

# %%
#pd.read_csv('../dataset/ref.csv', sep=';')
pd.read_csv('../dataset/ref.csv', delimiter=';')
# memrubah pemisah antar data pakai sep/delimiter
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
pd.read_csv('../dataset/Student_Marks.csv')
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df = pd.read_csv('../dataset/nbaallelo.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
pd.set_option('display.max.columns', None)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.shape 
#(baris,kolom)
# Out:
# (126314, 23)

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0            0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# ...

# %%
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126304          98            1     CLE  Cavaliers   95  1708.1705  1716.8708
# ...

# %%
df.sample(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 60719       30360  198901260NJN   NBA        0     1989   1/26/1989
# 119144      59573  201212180DEN   NBA        0     2013  12/18/2012
# 1492          747  194901120STB   NBA        1     1949   1/12/1949
#
#         seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 60719           40            0     NJN     Nets  109  1393.1718  1384.7565
# 119144          26            0     DEN  Nuggets  112  1588.0087  1595.9199
# 1492            26            0     CHS    Stags   75  1500.6069  1510.1331
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 60719   30.443682    SAC    Kings      112  1365.5725  1373.9878
# 119144  50.450169    SAS    Spurs      106  1694.2546  1686.3434
# 1492    47.999977    STB  Bombers       66  1394.7767  1385.2506
#
#        game_location game_result  forecast notes
# 60719              H           L  0.675796   NaN
# ...

# %% [markdown]
# # Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# ada team yang tidak memasukkan poin dalam satu pertandingan

# %% [markdown]
# ## Data Exploration

# %%
df [['team_id', 'fran_id', 'pts']]
# Out:
#        team_id    fran_id  pts
# 0          TRH    Huskies   66
# 1          NYK     Knicks   68
# 2          CHS      Stags   63
# 3          NYK     Knicks   47
# 4          DTF    Falcons   33
# ...        ...        ...  ...
# 126309     CLE  Cavaliers   82
# 126310     GSW   Warriors  104
# 126311     CLE  Cavaliers   91
# 126312     CLE  Cavaliers   97
# 126313     GSW   Warriors  105
#
# [126314 rows x 3 columns]

# %%
df['fran_id'].unique()
# Out:
# array(['Huskies', 'Knicks', 'Stags', 'Falcons', 'Capitols', 'Celtics',
#        'Steamrollers', 'Ironmen', 'Bombers', 'Rebels', 'Warriors',
#        'Baltimore', 'Jets', 'Pistons', 'Lakers', 'Kings', 'Hawks',
#        'Denver', 'Olympians', 'Redskins', 'Waterloo', 'Packers', 'Sixers',
#        'Wizards', 'Bulls', 'Thunder', 'Squires', 'Stars', 'Rockets',
#        'Colonels', 'Pacers', 'Nuggets', 'Spurs', 'Spirits', 'Sounds',
#        'Floridians', 'Nets', 'Condors', 'Bucks', 'Suns', 'Clippers',
#        'Cavaliers', 'Trailblazers', 'Sails', 'Jazz', 'Mavericks',
#        'Pelicans', 'Heat', 'Timberwolves', 'Magic', 'Grizzlies',
#        'Raptors', 'Hornets'], dtype=object)

# %%
df['fran_id'].value_counts().head(6)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Name: fran_id, dtype: int64

# %%
df['team_id'].value_counts().head(6)
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# CHI    4307
# Name: team_id, dtype: int64

# %% [markdown]
# Terdapat inkonsistensi pada nilai max, pada fran_id tertinggi lakers dan pada tream_id tertinggi BOS

# %%
df.loc[df['fran_id']=='Lakers',['team_id','fran_id']].value_counts()
# Out:
# team_id  fran_id
# LAL      Lakers     5078
# MNL      Lakers      946
# dtype: int64

# %% [markdown]
# ternyata terdapat 2 team_id untuk Lakers

# %%
df.loc[df['fran_id']=='Falcons', 'pts'].min()
# Out:
# 33

# %%
df.loc[df['fran_id']=='Falcons', 'pts'].max()
# Out:
# 92

# %%
df.loc[df['fran_id']=='Falcons', 'pts'].mean()
# Out:
# 63.28333333333333

# %% [markdown]
# ## Query

# %%
df[df['year_id']>2010 ]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df[
    (df['year_id']>2010) &
    (df['fran_id'] == 'Warriors')&
    (df['pts']>100) &
    (df['game_result']== 'W' )
    ][['year_id','fran_id', 'pts', 'game_result']]
# Out:
#         year_id   fran_id  pts game_result
# 113668     2011  Warriors  132           W
# 113700     2011  Warriors  109           W
# 113767     2011  Warriors  115           W
# 113853     2011  Warriors  109           W
# 113874     2011  Warriors  122           W
# ...         ...       ...  ...         ...
# 126301     2015  Warriors  104           W
# 126303     2015  Warriors  108           W
# 126308     2015  Warriors  103           W
# 126310     2015  Warriors  104           W
# 126313     2015  Warriors  105           W
#
# [193 rows x 4 columns]

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df[
    (df['is_playoffs']==1) &
    (df['fran_id'] == 'Lakers')&
    (df['game_location']== 'H') &
    (df['year_id']>1970 )
    ]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 23811       11906  197103240LAL   NBA        0     1971  3/24/1971
# 23827       11914  197103260LAL   NBA        0     1971  3/26/1971
# 23898       11950  197104010LAL   NBA        0     1971   4/1/1971
# 23934       11968  197104060LAL   NBA        0     1971   4/6/1971
# 23970       11986  197104140LAL   NBA        0     1971  4/14/1971
# ...           ...           ...   ...      ...      ...        ...
# 118345      59173  201205120LAL   NBA        0     2012  5/12/2012
# 118367      59184  201205180LAL   NBA        0     2012  5/18/2012
# 118372      59187  201205190LAL   NBA        0     2012  5/19/2012
# 120926      60464  201304260LAL   NBA        0     2013  4/26/2013
# 120940      60471  201304280LAL   NBA        0     2013  4/28/2013
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 23811           83            1     LAL  Lakers  100  1480.7465  1484.4449
# ...

# %% [markdown]
# Menggunakan .querry

# %%
df.query("is_playoffs == 1 & fran_id == 'Lakers' & game_location == 'H' & year_id > 1970 ")
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 23811       11906  197103240LAL   NBA        0     1971  3/24/1971
# 23827       11914  197103260LAL   NBA        0     1971  3/26/1971
# 23898       11950  197104010LAL   NBA        0     1971   4/1/1971
# 23934       11968  197104060LAL   NBA        0     1971   4/6/1971
# 23970       11986  197104140LAL   NBA        0     1971  4/14/1971
# ...           ...           ...   ...      ...      ...        ...
# 118345      59173  201205120LAL   NBA        0     2012  5/12/2012
# 118367      59184  201205180LAL   NBA        0     2012  5/18/2012
# 118372      59187  201205190LAL   NBA        0     2012  5/19/2012
# 120926      60464  201304260LAL   NBA        0     2013  4/26/2013
# 120940      60471  201304280LAL   NBA        0     2013  4/28/2013
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 23811           83            1     LAL  Lakers  100  1480.7465  1484.4449
# ...

# %% [markdown]
# ## Grouping and Agregating

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0  1309.6521  42.012257    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68  1300.0000  1306.7233             H           L  0.640065
# 1  Huskies       66  1300.0000  1293.2767             A           W  0.359935
# 2   Knicks       47  1306.7233  1297.0712             H           W  0.631101
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df.groupby('fran_id')['pts'].mean()
# Out:
# fran_id
# Baltimore        79.698073
# Bombers          71.457831
# Bucks           103.700050
# Bulls           101.525192
# Capitols         76.931271
# Cavaliers        99.846719
# Celtics         104.466233
# Clippers        101.934905
# Colonels        111.625296
# Condors         115.446512
# Denver           77.709677
# Falcons          63.283333
# Floridians      112.654545
# Grizzlies        95.161738
# Hawks           101.805635
# Heat             96.627162
# Hornets          94.506711
# Huskies          66.583333
# Ironmen          61.233333
# Jazz            102.153305
# Jets             74.700000
# Kings           103.971689
# Knicks          100.970185
# Lakers          105.817397
# Magic            99.427277
# Mavericks       102.634915
# Nets            101.755723
# Nuggets         108.199029
# Olympians        81.078014
# Pacers          103.687722
# Packers          86.013889
# Pelicans         97.956522
# Pistons         101.373097
# Raptors          96.921665
# ...

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %% [markdown]
# ## Columns Manipulation
#     - Create new cloumn
#     - Rename column
#     - Drop Column

# %%
df_new=df.copy()

# %%
df_new.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0  1309.6521  42.012257    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68  1300.0000  1306.7233             H           L  0.640065
# 1  Huskies       66  1300.0000  1293.2767             A           W  0.359935
# 2   Knicks       47  1306.7233  1297.0712             H           W  0.631101
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
# Create New Column
# np.absolute untuk membuat niali absolut tanpa -
df_new['selisih'] = np.absolute(df_new['pts'] - df_new['opp_pts'])

# %%
df_new.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes  selisih
# 0   NaN        2
# 1   NaN        2

# %%
# Rename
df_new.rename(columns={'game_location' : 'loc',
            'game_result' : 'result'})
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df_new.rename(columns={'game_location' : 'loc',
            'game_result' : 'result'}, inplace= True )

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0  1309.6521  42.012257    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68  1300.0000  1306.7233             H           L  0.640065
# 1  Huskies       66  1300.0000  1293.2767             A           W  0.359935
# 2   Knicks       47  1306.7233  1297.0712             H           W  0.631101
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
# Drop Column
# Axis 0 = Baris
# Axis 1 = Kolom
df_new = df_new.drop(['elo_i', 'elo_n'], axis=1)

# %%
df_new.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66  40.294830    NYK   Knicks       68
# 1            0     NYK   Knicks   68  41.705170    TRH  Huskies       66
# 2            0     CHS    Stags   63  42.012257    NYK   Knicks       47
#
#    opp_elo_i  opp_elo_n loc result  forecast notes  selisih
# 0  1300.0000  1306.7233   H      L  0.640065   NaN        2
# 1  1300.0000  1293.2767   A      W  0.359935   NaN        2
# 2  1306.7233  1297.0712   H      W  0.631101   NaN       16

# %%
# creating new column based on existing information using loop

# siapkan list kosong
# buat program loop -> selisih pts dengan opp_pts
# simpan hasil per baris ke list kosong
# convert list yang sudah terisi menjadi kolom

hasil = []

# Menggunakan iloc
# df_new.iloc[:, 10] index kolom pts
# df_new.iloc[:, 14] index kolom opp_pts
# atau bisa menggunakan loc
# df_new.iloc[:, pts] kolom pts
# df_new.iloc[:, opp_pts] kolom opp pts

for i in range(len(df_new)):
    selisih = df_new.iloc[i,10]- df_new.loc[i, 'opp_pts']
    hasil.append(selisih)
df_new['menggunakan loop'] = np.abs(hasil)

# %%
df_new.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts  win_equiv opp_id      opp_fran  \
# 0            0     TRH       Huskies   66  40.294830    NYK        Knicks
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gameorder         126314 non-null  int64
#  1   game_id           126314 non-null  object
#  2   lg_id             126314 non-null  object
#  3   _iscopy           126314 non-null  int64
#  4   year_id           126314 non-null  int64
#  5   date_game         126314 non-null  object
#  6   seasongame        126314 non-null  int64
#  7   is_playoffs       126314 non-null  int64
#  8   team_id           126314 non-null  object
#  9   fran_id           126314 non-null  object
#  10  pts               126314 non-null  int64
#  11  win_equiv         126314 non-null  float64
#  12  opp_id            126314 non-null  object
#  13  opp_fran          126314 non-null  object
#  14  opp_pts           126314 non-null  int64
#  15  opp_elo_i         126314 non-null  float64
# ...

# %%
df_new['notes'].isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 126309    True
# 126310    True
# 126311    True
# 126312    True
# 126313    True
# Name: notes, Length: 126314, dtype: bool

# %%
missing_values = ["n/a", "na", "--"]

# %%
df2 = pd.read_csv('../dataset/nbaallelo.csv',na_values = missing_values)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df2
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...
